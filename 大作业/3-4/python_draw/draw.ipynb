# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# plt.gca().set_color_cycle(['blur','red'])
plt.legend(['时延-传输时间曲线','时延-吞吐率曲线'])

# %%
x = [0, 5, 10, 20, 33]
y = [34, 227, 256, 277, 301]
plt.plot(x, y)
x2=[0,5,10,20,33]
y2=[54628,8182.17,7255.28,6705.24,6170.6]
plt.plot(x2,y2)
plt.show()

# %%
x = [0, 5, 10, 20, 33]
y1 = [34, 227, 256, 277, 301]
y2 = [54628,8182.17,7255.28,6705.24,6170.6]
_,ax=plt.subplots()
ax.plot(x,y1,'b',label='时延')
ax.set_xlabel('x')
ax.set_ylabel('y1',color='b')
ax2 = ax.twinx()
ax2.plot(x,y2,'r',label='吞吐率')
ax2.set_ylabel('y2',color='r')
# Out:
# Text(0, 0.5, 'y2')

# %%
x = [0, 5, 10, 20, 33]
y= [18,180,284,472,842]
x2 = [0, 5, 10, 20, 33]
y2 = [16,134,210,551,722]
plt.plot(x,y)
plt.plot(x2,y2)
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = [0, 5, 10, 20, 33]
y= [103186,10318.6,6539.98,3935.07,2205.88]
x2 = [0, 5, 10, 20, 33]
y2 = [116085,13860.8,8844.54,3370.88,2572.51]
plt.plot(x,y)
plt.plot(x2,y2)
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np

# 这两行代码解决 plt 中文显示的问题
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# 输入统计数据
waters = ('0', '5', '10', '20', '33')
high = [103186,10318.6,6539.98,3935.07,2205.88]
low = [116085,13860.8,8844.54,3370.88,2572.51]

bar_width = 0.3  # 条形宽度
index_male = np.arange(len(waters))
index_female = index_male + bar_width

# 使用两次 bar 函数画出两组条形图
plt.bar(index_male, height=high, width=bar_width, color='mediumaquamarine', label='停等机制')
plt.bar(index_female, height=low, width=bar_width, color='salmon', label='滑动窗口机制')

plt.legend()  # 显示图例
plt.xticks(index_male + bar_width/2, waters)  # 让横坐标轴刻度显示 waters 里的饮用水， index_male + bar_width/2 为横坐标轴刻度的位置
plt.ylabel('吞吐率：byte/s')  # 纵坐标轴标题
plt.title('停等机制-滑动窗口机制吞吐率比对图')  # 图形标题

plt.show()

# %%
x = [0,25,50,100,250]
y= [180,374,561,932,2119]
x2 = [0,25,50,100,250]
y2 = [134,322,513,928,2083]
plt.plot(x,y)
plt.plot(x2,y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 这两行代码解决 plt 中文显示的问题
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# 输入统计数据
waters = ('0', '25', '50', '100', '250')
high = [10319,4966,3311,1993,877]
low = [13861,5768,3621,2001,892]

bar_width = 0.3  # 条形宽度
index_male = np.arange(len(waters))
index_female = index_male + bar_width

# 使用两次 bar 函数画出两组条形图
plt.bar(index_male, height=high, width=bar_width, color='mediumaquamarine', label='停等机制')
plt.bar(index_female, height=low, width=bar_width, color='salmon', label='滑动窗口机制')

plt.legend()  # 显示图例
plt.xticks(index_male + bar_width/2, waters)  # 让横坐标轴刻度显示 waters 里的饮用水， index_male + bar_width/2 为横坐标轴刻度的位置
plt.ylabel('吞吐率：byte/s')  # 纵坐标轴标题
plt.title('停等机制-滑动窗口机制吞吐率比对图')  # 图形标题

plt.show()
