# %%
import matplotlib.pyplot as plt
import numpy as np
x = [0, 5, 10, 20, 33]
y = [34,227,256,277,301]
plt.plot(x, y)
y2=[19,203,308,551,722]
plt.plot(x,y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 这两行代码解决 plt 中文显示的问题
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# 输入统计数据
waters = ('0', '5', '10', '20', '33')
high = [54628,8182,7255,6705,6171]
low = [97755,9150,6030,3371,2573]

bar_width = 0.3  # 条形宽度
index_male = np.arange(len(waters))
index_female = index_male + bar_width

# 使用两次 bar 函数画出两组条形图
plt.bar(index_male, height=high, width=bar_width, color='mediumaquamarine', label='有拥塞控制')
plt.bar(index_female, height=low, width=bar_width, color='salmon', label='无拥塞控制')

plt.legend()  # 显示图例
plt.xticks(index_male + bar_width/2, waters)  # 让横坐标轴刻度显示 waters 里的饮用水， index_male + bar_width/2 为横坐标轴刻度的位置
plt.ylabel('吞吐率：byte/s')  # 纵坐标轴标题
plt.title('拥塞控制对传输速率的影响')  # 图形标题

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = [0, 20, 50, 100]
y = [34,183,401,763]
plt.plot(x, y)
y2=[19,192,435,775]
plt.plot(x,y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 这两行代码解决 plt 中文显示的问题
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# 输入统计数据
waters = ('0', '20', '50', '100')
high = [54628,10149,4632,2434]
low = [97750,9673,4270,2396]

bar_width = 0.3  # 条形宽度
index_male = np.arange(len(waters))
index_female = index_male + bar_width

# 使用两次 bar 函数画出两组条形图
plt.bar(index_male, height=high, width=bar_width, color='mediumaquamarine', label='有拥塞控制')
plt.bar(index_female, height=low, width=bar_width, color='salmon', label='无拥塞控制')

plt.legend()  # 显示图例
plt.xticks(index_male + bar_width/2, waters)  # 让横坐标轴刻度显示 waters 里的饮用水， index_male + bar_width/2 为横坐标轴刻度的位置
plt.ylabel('吞吐率：byte/s')  # 纵坐标轴标题
plt.title('拥塞控制对传输速率的影响')  # 图形标题

plt.show()
